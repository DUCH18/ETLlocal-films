# %%
import json
import pandas as pd
from pathlib import Path


path = '../data/raw/latest_films.json' 

with open(path) as f:
    data = json.load(f)
        
df = pd.json_normalize(data)
df.head()
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /6YjnTRBz704LF1uJ3ZC4wsS9T8r.jpg   [28, 80, 53]  1290821
# 1  False  /7HKpc11uQfxnw0Y8tRUYn1fsKqE.jpg  [878, 28, 53]  1236153
# 2  False  /z4hZZQ1GRuNGdeeWfKZIt8PXrmX.jpg           [28]  1244975
# 3  False  /hYgUkH7TusddHRtelj53I6gFOWR.jpg       [28, 53]   799882
# 4  False  /1gLFGrxHqQebqLWpISmoFR6XWtJ.jpg       [28, 53]  1088434
#
#   original_language original_title  \
# 0                en        Shelter
# 1                en          Mercy
# 2                fr  Les Orphelins
# 3                en      The Bluff
# 4                en       Hellfire
#
#                                             overview  popularity  \
# 0  A man living in self-imposed exile on a remote...    434.2537
# 1  In the near future, a detective stands on tria...    379.2699
# 2  Gab and Driss, childhood friends on bad terms ...    206.9224
# 3  When her tranquil life on a remote island is s...    358.4436
# ...
